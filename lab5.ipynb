# %%
from nltk.corpus import names

# %%
def gender_features(word):
                   return{'last letter':word[-1]}

# %%
gender_features('Obama')
# Out:
# {'last letter': 'a'}

# %%
labeled_names = ([(name,'male') for name in names.words('male.txt')] + [(name, 'female')  for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)
featuresets=[(gender_features(n),gender) for(n,gender)in labeled_names]

# %%
featuresets
# Out:
# [({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'w'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'd'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'k'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'u'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'v'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'x'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'c'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'b'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'w'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'f'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'f'}, 'male'),
#  ({'last letter': 'x'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'p'}, 'male'),
#  ({'last letter': 'v'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'a'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'o'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'u'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'v'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'a'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'x'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'p'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'm'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'f'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'p'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'o'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'g'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'b'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'g'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'c'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'f'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'g'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'i'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'm'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'o'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'v'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'c'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'r'}, 'female'),
#  ({'last letter': 'g'}, 'male'),
#  ({'last letter': 'a'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'k'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'm'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'v'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'o'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'l'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'b'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'y'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 's'}, 'male'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'i'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'z'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'n'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 't'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'n'}, 'male'),
#  ({'last letter': 's'}, 'female'),
#  ({'last letter': 'r'}, 'male'),
#  ({'last letter': 'h'}, 'female'),
#  ({'last letter': 'h'}, 'male'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'l'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'a'}, 'female'),
#  ({'last letter': 'o'}, 'male'),
#  ({'last letter': 't'}, 'male'),
#  ({'last letter': 'e'}, 'female'),
#  ({'last letter': 'y'}, 'female'),
#  ({'last letter': 'd'}, 'male'),
#  ({'last letter': 'i'}, 'male'),
#  ...]

# %%
train_set, test_set=featuresets[5000:], featuresets[:2000]
import nltk
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('ishan'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Shravani'))
# Out:
# 'female'
