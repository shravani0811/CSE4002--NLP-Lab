# %%
import spacy

# %%
sp = spacy.load("en")

# %%
sp.vocab.length
# Out:
# 489

# %%
#Opening paragraph from a tale of two cities
tex = sp("It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way—in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only.")

# %%
# Finding pos tags of all words
[(token.text, token.pos_) for token in tex]
# Out:
# [('It', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('best', 'ADJ'),
#  ('of', 'ADP'),
#  ('times', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('worst', 'ADJ'),
#  ('of', 'ADP'),
#  ('times', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('age', 'NOUN'),
#  ('of', 'ADP'),
#  ('wisdom', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('age', 'NOUN'),
#  ('of', 'ADP'),
#  ('foolishness', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('epoch', 'NOUN'),
#  ('of', 'ADP'),
#  ('belief', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('epoch', 'NOUN'),
#  ('of', 'ADP'),
#  ('incredulity', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('season', 'NOUN'),
#  ('of', 'ADP'),
#  ('Light', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('season', 'NOUN'),
#  ('of', 'ADP'),
#  ('Darkness', 'PROPN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('spring', 'NOUN'),
#  ('of', 'ADP'),
#  ('hope', 'NOUN'),
#  (',', 'PUNCT'),
#  ('it', 'PRON'),
#  ('was', 'AUX'),
#  ('the', 'DET'),
#  ('winter', 'NOUN'),
#  ('of', 'ADP'),
#  ('despair', 'NOUN'),
#  (',', 'PUNCT'),
#  ('we', 'PRON'),
#  ('had', 'AUX'),
#  ('everything', 'PRON'),
#  ('before', 'ADP'),
#  ('us', 'PRON'),
#  (',', 'PUNCT'),
#  ('we', 'PRON'),
#  ('had', 'AUX'),
#  ('nothing', 'PRON'),
#  ('before', 'ADP'),
#  ('us', 'PRON'),
#  (',', 'PUNCT'),
#  ('we', 'PRON'),
#  ('were', 'AUX'),
#  ('all', 'ADV'),
#  ('going', 'VERB'),
#  ('direct', 'ADJ'),
#  ('to', 'ADP'),
#  ('Heaven', 'PROPN'),
#  (',', 'PUNCT'),
#  ('we', 'PRON'),
#  ('were', 'AUX'),
#  ('all', 'ADV'),
#  ('going', 'VERB'),
#  ('direct', 'ADJ'),
#  ('the', 'DET'),
#  ('other', 'ADJ'),
#  ('way', 'NOUN'),
#  ('—', 'PUNCT'),
#  ('in', 'ADP'),
#  ('short', 'ADJ'),
#  (',', 'PUNCT'),
#  ('the', 'DET'),
#  ('period', 'NOUN'),
#  ('was', 'AUX'),
#  ('so', 'ADV'),
#  ('far', 'ADV'),
#  ('like', 'SCONJ'),
#  ('the', 'DET'),
#  ('present', 'ADJ'),
#  ('period', 'NOUN'),
#  (',', 'PUNCT'),
#  ('that', 'SCONJ'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('its', 'DET'),
#  ('noisiest', 'ADJ'),
#  ('authorities', 'NOUN'),
#  ('insisted', 'VERB'),
#  ('on', 'ADP'),
#  ('its', 'DET'),
#  ('being', 'AUX'),
#  ('received', 'VERB'),
#  (',', 'PUNCT'),
#  ('for', 'ADP'),
#  ('good', 'NOUN'),
#  ('or', 'CCONJ'),
#  ('for', 'ADP'),
#  ('evil', 'NOUN'),
#  (',', 'PUNCT'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('superlative', 'ADJ'),
#  ('degree', 'NOUN'),
#  ('of', 'ADP'),
#  ('comparison', 'NOUN'),
#  ('only', 'ADV'),
#  ('.', 'PUNCT')]

# %%
#what does each tag mean?
[(token.text, token.pos_, spacy.explain(token.pos_)) for token in tex]
# Out:
# [('It', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('best', 'ADJ', 'adjective'),
#  ('of', 'ADP', 'adposition'),
#  ('times', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('worst', 'ADJ', 'adjective'),
#  ('of', 'ADP', 'adposition'),
#  ('times', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('age', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('wisdom', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('age', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('foolishness', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('epoch', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('belief', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('epoch', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('incredulity', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('season', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('Light', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('season', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('Darkness', 'PROPN', 'proper noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('spring', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('hope', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('it', 'PRON', 'pronoun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('the', 'DET', 'determiner'),
#  ('winter', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('despair', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('we', 'PRON', 'pronoun'),
#  ('had', 'AUX', 'auxiliary'),
#  ('everything', 'PRON', 'pronoun'),
#  ('before', 'ADP', 'adposition'),
#  ('us', 'PRON', 'pronoun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('we', 'PRON', 'pronoun'),
#  ('had', 'AUX', 'auxiliary'),
#  ('nothing', 'PRON', 'pronoun'),
#  ('before', 'ADP', 'adposition'),
#  ('us', 'PRON', 'pronoun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('we', 'PRON', 'pronoun'),
#  ('were', 'AUX', 'auxiliary'),
#  ('all', 'ADV', 'adverb'),
#  ('going', 'VERB', 'verb'),
#  ('direct', 'ADJ', 'adjective'),
#  ('to', 'ADP', 'adposition'),
#  ('Heaven', 'PROPN', 'proper noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('we', 'PRON', 'pronoun'),
#  ('were', 'AUX', 'auxiliary'),
#  ('all', 'ADV', 'adverb'),
#  ('going', 'VERB', 'verb'),
#  ('direct', 'ADJ', 'adjective'),
#  ('the', 'DET', 'determiner'),
#  ('other', 'ADJ', 'adjective'),
#  ('way', 'NOUN', 'noun'),
#  ('—', 'PUNCT', 'punctuation'),
#  ('in', 'ADP', 'adposition'),
#  ('short', 'ADJ', 'adjective'),
#  (',', 'PUNCT', 'punctuation'),
#  ('the', 'DET', 'determiner'),
#  ('period', 'NOUN', 'noun'),
#  ('was', 'AUX', 'auxiliary'),
#  ('so', 'ADV', 'adverb'),
#  ('far', 'ADV', 'adverb'),
#  ('like', 'SCONJ', 'subordinating conjunction'),
#  ('the', 'DET', 'determiner'),
#  ('present', 'ADJ', 'adjective'),
#  ('period', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('that', 'SCONJ', 'subordinating conjunction'),
#  ('some', 'DET', 'determiner'),
#  ('of', 'ADP', 'adposition'),
#  ('its', 'DET', 'determiner'),
#  ('noisiest', 'ADJ', 'adjective'),
#  ('authorities', 'NOUN', 'noun'),
#  ('insisted', 'VERB', 'verb'),
#  ('on', 'ADP', 'adposition'),
#  ('its', 'DET', 'determiner'),
#  ('being', 'AUX', 'auxiliary'),
#  ('received', 'VERB', 'verb'),
#  (',', 'PUNCT', 'punctuation'),
#  ('for', 'ADP', 'adposition'),
#  ('good', 'NOUN', 'noun'),
#  ('or', 'CCONJ', 'coordinating conjunction'),
#  ('for', 'ADP', 'adposition'),
#  ('evil', 'NOUN', 'noun'),
#  (',', 'PUNCT', 'punctuation'),
#  ('in', 'ADP', 'adposition'),
#  ('the', 'DET', 'determiner'),
#  ('superlative', 'ADJ', 'adjective'),
#  ('degree', 'NOUN', 'noun'),
#  ('of', 'ADP', 'adposition'),
#  ('comparison', 'NOUN', 'noun'),
#  ('only', 'ADV', 'adverb'),
#  ('.', 'PUNCT', 'punctuation')]

# %%
#frequency of POS tags
pos_freq = tex.count_by(spacy.attrs.POS)
for k,v in sorted(pos_freq.items()):
    print(f'{tex.vocab[k].text:{6}}: {v}')
# Out:
# ADJ   : 9
# ADP   : 20
# ADV   : 5
# AUX   : 16
# CCONJ : 1
# DET   : 17
# NOUN  : 25
# PRON  : 18
# PROPN : 2
# PUNCT : 19
# SCONJ : 2
# VERB  : 4

# %%
tex0 = sp("It's a good time to visit N.Y.C. this Sept. for 30,000 people.")

# %%
for token in tex0:
    print (token.text)
# Out:
# It
# 's
# a
# good
# time
# to
# visit
# N.Y.C.
# this
# Sept.
# for
# 30,000
# people
# .

# %%
# Spacy visualiser
from spacy import displacy

# %%
tex1=sp("The dog walked up the hill.")

# %%
[(token.text, token.dep_) for token in tex1]
# Out:
# [('The', 'det'),
#  ('dog', 'nsubj'),
#  ('walked', 'ROOT'),
#  ('up', 'prep'),
#  ('the', 'det'),
#  ('hill', 'pobj'),
#  ('.', 'punct')]

# %%
displacy.render(tex1, style="dep", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="20e8e8b21a9e40409c98281efd304fe2-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">walked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">hill.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20e8e8b21a9e40409c98281efd304fe2-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20e8e8b21a9e40409c98281efd304fe2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20e8e8b21a9e40409c98281efd304fe2-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20e8e8b21a9e40409c98281efd304fe2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20e8e8b21a9e40409c98281efd304fe2-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20e8e8b21a9e40409c98281efd304fe2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20e8e8b21a9e40409c98281efd304fe2-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20e8e8b21a9e40409c98281efd304fe2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-20e8e8b21a9e40409c98281efd304fe2-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-20e8e8b21a9e40409c98281efd304fe2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
options = {"compact": True, "color": "blue"}
displacy.render(tex1, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6f6fcac640fe413dad165395f0dc10ff-0" class="displacy" width="950" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: blue; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">walked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">hill.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f6fcac640fe413dad165395f0dc10ff-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f6fcac640fe413dad165395f0dc10ff-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f6fcac640fe413dad165395f0dc10ff-0-1" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f6fcac640fe413dad165395f0dc10ff-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,154.0 L208,146.0 216,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f6fcac640fe413dad165395f0dc10ff-0-2" stroke-width="2px" d="M362,152.0 362,127.0 497.0,127.0 497.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f6fcac640fe413dad165395f0dc10ff-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M497.0,154.0 L501.0,146.0 493.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f6fcac640fe413dad165395f0dc10ff-0-3" stroke-width="2px" d="M662,152.0 662,127.0 797.0,127.0 797.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f6fcac640fe413dad165395f0dc10ff-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,154.0 L658,146.0 666,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f6fcac640fe413dad165395f0dc10ff-0-4" stroke-width="2px" d="M512,152.0 512,102.0 800.0,102.0 800.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f6fcac640fe413dad165395f0dc10ff-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M800.0,154.0 L804.0,146.0 796.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
tex2 = sp("John has played basketball since 2010. He follows NBA")
displacy.render(tex2, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has played basketball since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . He follows
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
tex3 = sp("Stacy has played basketball since 2010. Her favourite NBA team is the Lakers")
displacy.render(tex3, style="ent")
for entity in tex3.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Stacy has played basketball since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Her favourite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team is the Lakers</div></span>
# 2010 - DATE - Absolute or relative dates or periods
# NBA - ORG - Companies, agencies, institutions, etc.

# %%
# recognizing eliza as a person and lakers as an org
from spacy.tokens import Span

PERSON = tex3.vocab.strings[u'PERSON']
ORG = tex3.vocab.strings[u'ORG']
new_entity = Span(tex3, 0, 1, label=PERSON)
new_entity2 = Span(tex3, 13, 14, label=ORG)
tex3.ents = list(tex3.ents) + [new_entity] + [new_entity2]

# %%
displacy.render(tex3, style="ent")
for entity in tex3.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stacy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has played basketball since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Her favourite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  team is the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lakers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
# Stacy - PERSON - People, including fictional
# 2010 - DATE - Absolute or relative dates or periods
# NBA - ORG - Companies, agencies, institutions, etc.
# Lakers - ORG - Companies, agencies, institutions, etc.

# %%
from spacy.lang.en import English

nlp = English()  
sentencizer = nlp.create_pipe("sentencizer")
nlp.add_pipe(sentencizer)
for sent in tex.sents:
    print(sent.text)
# Out:
# It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way—in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only.

# %%
# One very long sentence. As an example, I will make ',' a sentence boundary. Can be used for ellipses and emojis which are common sentence boundaries on social media

def set_custom_boundaries(tex):
    for token in tex[:-1]:
        if token.text == ",":
            tex[token.i+1].is_sent_start = True
    return tex

# %%
sp.add_pipe(set_custom_boundaries, before="parser")

# %%
tex = sp("It was the best of times, it was the worst of times, it was the age of wisdom, it was the age of foolishness, it was the epoch of belief, it was the epoch of incredulity, it was the season of Light, it was the season of Darkness, it was the spring of hope, it was the winter of despair, we had everything before us, we had nothing before us, we were all going direct to Heaven, we were all going direct the other way—in short, the period was so far like the present period, that some of its noisiest authorities insisted on its being received, for good or for evil, in the superlative degree of comparison only.")
for sent in tex.sents:
    print(sent.text)
# Out:
# It was the best of times,
# it was the worst of times,
# it was the age of wisdom,
# it was the age of foolishness,
# it was the epoch of belief,
# it was the epoch of incredulity,
# it was the season of Light,
# it was the season of Darkness,
# it was the spring of hope,
# it was the winter of despair,
# we had everything before us,
# we had nothing before us,
# we were all going direct to Heaven,
# we were all going direct the other way—in short,
# the period was so far like the present period,
# that some of its noisiest authorities insisted on its being received,
# for good or for evil,
# in the superlative degree of comparison only.

# %%
nlp = spacy.load('en_core_web_lg')

# %%
nlp.pipe_names
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x2c24ae52ec8>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x2c247f29dc8>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x2c247f29b88>)]

# %%
tokens = nlp("apple dog broken banana cat onomatopoeia asdfkj")
# asdfkj is a variant of "keyboard smashing" - a phenomenon which is seen on most social media
for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# apple True 7.1346846 False
# dog True 7.0336733 False
# broken True 5.5968375 False
# banana True 6.700014 False
# cat True 6.6808186 False
# onomatopoeia True 6.8262777 False
# asdfkj False 0.0 True

# %%
# comparing similarities
for tok1 in tokens:
    for tok2 in tokens:
        print(tok1.text, tok2.text, tok1.similarity(tok2))
# Out:
# apple apple 1.0
# apple dog 0.2633902
# apple broken 0.30717564
# apple banana 0.5831844
# apple cat 0.28213844
# apple onomatopoeia 0.041739788
# apple asdfkj 0.0
# dog apple 0.2633902
# dog dog 1.0
# dog broken 0.2948628
# dog banana 0.24327648
# dog cat 0.80168545
# dog onomatopoeia 0.02036748
# dog asdfkj 0.0
# broken apple 0.30717564
# broken dog 0.2948628
# broken broken 1.0
# broken banana 0.25774238
# broken cat 0.30218005
# broken onomatopoeia -0.06426965
# broken asdfkj 0.0
# banana apple 0.5831844
# banana dog 0.24327648
# banana broken 0.25774238
# banana banana 1.0
# banana cat 0.28154367
# banana onomatopoeia 0.046276174
# banana asdfkj 0.0
# cat apple 0.28213844
# cat dog 0.80168545
# cat broken 0.30218005
# cat banana 0.28154367
# cat cat 1.0
# cat onomatopoeia 0.040334832
# cat asdfkj 0.0
# onomatopoeia apple 0.041739788
# onomatopoeia dog 0.02036748
# onomatopoeia broken -0.06426965
# onomatopoeia banana 0.046276174
# onomatopoeia cat 0.040334832
# onomatopoeia onomatopoeia 1.0
# onomatopoeia asdfkj 0.0
# asdfkj apple 0.0
# asdfkj dog 0.0
# asdfkj broken 0.0
# asdfkj banana 0.0
# asdfkj cat 0.0
# asdfkj onomatopoeia 0.0
# asdfkj asdfkj 1.0
# C:\Users\aradh\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   after removing the cwd from sys.path.

# %%
tex4 = nlp("I like cats")
tex5 = nlp("I like dogs")

# %%
# Compare 2 tokens
tex4[2].similarity(tex5[2])
# Out:
# 0.83117634

# %%
# SpaCy recognition might be limited

test1 = nlp("Aradhita wants a cat. Her cat wants a dog. But horses are the best.")
for ent in test1.ents:
    print(ent.text, ent.label_)
# Out:
# Aradhita ORG

# %%
# I want SpaCy to identify products, and to identify my name as a person

# %%
ner=nlp.get_pipe("ner")
#ner is pipeline component

# %%
#random training data, I am also trying to train a new entity called animal
TRAINING_DATA=[
    ("I left Vellore yesterday.", {"entities": [(7, 14, "GPE")]}),
    ("I need to buy more clothes.", {"entities": [(19, 26, "PRODUCT")]}),
    ("I rented a house.", {"entities": [(11, 16, "PRODUCT")]}),
    ("Fridge needs to be replaced ASAP ", {"entities": [(0,6, "PRODUCT")]}),
    ("Fridge can be ordered in Amazon ", {"entities": [(0,6, "PRODUCT")]}),
    ("There has been severe flooding in North India", {"entities": [(34, 45, "GPE")]}),
    ("I got my truck stolen", {"entities": [(9,14, "PRODUCT")]}),
    ("Aprajita orders clothes from amazon", {"entities": [(0,8, "PERSON")]}),
    ("I recently ordered from Shoppers Stop", {"entities": [(24,37,"ORG")]}),
    ("I bought a new bicycle", {"entities": [(15,22, "PRODUCT")]}),
    ("I donated my old toys", {"entities": [(17,21, "PRODUCT")]}),
    ("I bought a fancy new watch", {"entities": [(21,26, "PRODUCT")]}),
    ("I rented a cabin for our vacation", {"entities": [(11,16, "PRODUCT")]}),
    ("I borrowed a ball from our neighbour", {"entities": [(13,17, "PRODUCT")]}),
    ("I repaired my car", {"entities": [(14,17, "PRODUCT")]}),
    ("I got my computer fixed", {"entities": [(9,17, "PRODUCT")]}),
    ("Richa is starting school today", {"entities":[(0,5,"PERSON")]}),
    ("They adopted a boy named Amar", {"entities":[(25, 29,"PERSON")]}),
    ("Sanjay Dutt released a new film", {"entities":[(0,11,"PERSON")]}),
    ("Horses are too tall and they will hurt your feelings", {"entities":[(0, 6, "ANIMAL")]}),
    ("I want a dog", {"entities":[(9,12,"ANIMAL")]}),
    ("Cats are known to be evil", {"entities":[(0,4,"ANIMAL")]}),
    ("I saw a bird today", {"entities":[(8, 12, "ANIMAL")]}),
    ("Snoopy is a dog", {"entities":[(12,15,"ANIMAL")]}),
    ("Rio is a movie about birds", {"entities":[(21, 26,"ANIMAL")]}),
    ("Dogs should not eat chocolate", {"entities":[(0,4,"ANIMALS")]}),
    ("Cows give milk", {"entities":[(0,4,"ANIMALS")]}),
    ("Goats eat grass", {"entities":[(0, 5, "ANIMALS")]}),
    ("I do not buy Donkeys on Amazon", {"entities":[(13, 20, "ANIMALS")]}),
    ("Tigers are predators", {"entities":[(0, 6, "ANIMALS")]}),
    ("Rachna uses Amazon regularly", {"entities":[(0,6,"PERSON")]}),
    ("Archana uses Flipkart to order clothes", {"entities":[(0, 7, "PERSON")]}),
    ("Aparna has a purse", {"entities":[(0, 6, "PERSON")]})
   ]

# %%
# Adding labels to the `ner`

for _, annotations in TRAINING_DATA:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
# Disable pipeline components that should not be changed
pipe_exc = ["ner", "trf_wordpiecer", "trf_tok2vec"]
disabled_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exc]

# %%
# We need random to randomize ip, minibatch to create minibatches of text data, compouding func to yield an infinite series of compouding values
import random
from spacy.util import minibatch, compounding
from pathlib import Path

# %%
# TRAINING THE MODEL
with nlp.disable_pipes(*disabled_pipes):

  # Training for 180 iterations
  for iteration in range(180):

    # shuffling examples  before every iteration
    random.shuffle(TRAINING_DATA)
    losses = {}
    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAINING_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
        print("Losses", losses)
# Out:
# Losses {'ner': 13.296498000621796}
# Losses {'ner': 36.52636879682541}
# Losses {'ner': 51.27628618478775}
# Losses {'ner': 78.09206920862198}
# Losses {'ner': 100.09135013818741}
# Losses {'ner': 124.22386175394058}
# Losses {'ner': 144.29460698366165}
# Losses {'ner': 161.07301169633865}
# Losses {'ner': 168.07350224260935}
# Losses {'ner': 18.900981903076172}
# Losses {'ner': 34.708202838897705}
# Losses {'ner': 47.86578910052776}
# Losses {'ner': 75.4342643469572}
# Losses {'ner': 106.97110812366009}
# Losses {'ner': 133.28087060153484}
# Losses {'ner': 167.75682799518108}
# Losses {'ner': 183.59374026954174}
# Losses {'ner': 185.41481411298037}
# Losses {'ner': 22.266671419143677}
# Losses {'ner': 38.98586678504944}
# Losses {'ner': 56.914355665373705}
# Losses {'ner': 81.49305668466081}
# Losses {'ner': 110.428072124648}
# Losses {'ner': 130.881619125533}
# Losses {'ner': 153.8698855935811}
# Losses {'ner': 173.45071807496538}
# Losses {'ner': 176.72583468176458}
# Losses {'ner': 28.51737880706787}
# Losses {'ner': 49.70157480239868}
# Losses {'ner': 67.61417627334595}
# Losses {'ner': 88.03756785392761}
# Losses {'ner': 108.21631860733032}
# Losses {'ner': 123.60764193534851}
# Losses {'ner': 134.6382759809494}
# Losses {'ner': 151.82984161376953}
# Losses {'ner': 158.48957024514675}
# Losses {'ner': 24.637468576431274}
# Losses {'ner': 48.57840871810913}
# Losses {'ner': 70.40636157989502}
# Losses {'ner': 91.89532160758972}
# Losses {'ner': 110.68511974811554}
# Losses {'ner': 125.4104163646698}
# Losses {'ner': 144.0050848722458}
# Losses {'ner': 164.0732218027115}
# Losses {'ner': 166.79695311188698}
# Losses {'ner': 18.73633360862732}
# Losses {'ner': 32.44955122470856}
# Losses {'ner': 51.41821825504303}
# Losses {'ner': 71.75758183002472}
# Losses {'ner': 88.01895546913147}
# Losses {'ner': 108.2728955745697}
# Losses {'ner': 124.86810404062271}
# Losses {'ner': 135.6567948386073}
# Losses {'ner': 138.13921488728374}
# Losses {'ner': 14.865453958511353}
# Losses {'ner': 30.14316415786743}
# Losses {'ner': 44.58168685436249}
# Losses {'ner': 62.43753147125244}
# Losses {'ner': 76.05589818954468}
# Losses {'ner': 87.55132532119751}
# Losses {'ner': 106.79892349243164}
# Losses {'ner': 124.36927103996277}
# Losses {'ner': 130.9463182091713}
# Losses {'ner': 21.85718870162964}
# Losses {'ner': 40.5937933921814}
# Losses {'ner': 55.71702301502228}
# Losses {'ner': 77.07174503803253}
# Losses {'ner': 95.63133561611176}
# Losses {'ner': 115.26452660560608}
# Losses {'ner': 137.78689312934875}
# Losses {'ner': 150.8690128326416}
# Losses {'ner': 156.05308991670609}
# Losses {'ner': 16.286073446273804}
# Losses {'ner': 30.994961619377136}
# Losses {'ner': 49.561349272727966}
# Losses {'ner': 70.3785389661789}
# Losses {'ner': 89.23907196521759}
# Losses {'ner': 106.31490623950958}
# Losses {'ner': 121.86608850955963}
# Losses {'ner': 142.53171050548553}
# Losses {'ner': 148.63365978002548}
# Losses {'ner': 10.277673840522766}
# Losses {'ner': 27.755936980247498}
# Losses {'ner': 41.09434115886688}
# Losses {'ner': 57.86065065860748}
# Losses {'ner': 70.83130753040314}
# Losses {'ner': 85.974170088768}
# Losses {'ner': 109.46557700634003}
# Losses {'ner': 128.34219789505005}
# Losses {'ner': 137.1252855360508}
# Losses {'ner': 16.240697026252747}
# Losses {'ner': 36.48811447620392}
# Losses {'ner': 50.14665102958679}
# Losses {'ner': 69.72950077056885}
# Losses {'ner': 91.24997782707214}
# Losses {'ner': 105.90120470523834}
# Losses {'ner': 124.74787771701813}
# Losses {'ner': 137.06579184532166}
# Losses {'ner': 142.060300886631}
# Losses {'ner': 16.86408233642578}
# Losses {'ner': 34.34591317176819}
# Losses {'ner': 50.45982527732849}
# Losses {'ner': 66.86333107948303}
# Losses {'ner': 79.69900298118591}
# Losses {'ner': 100.25592923164368}
# Losses {'ner': 115.8359203338623}
# Losses {'ner': 133.30603262782097}
# Losses {'ner': 139.28977002948523}
# Losses {'ner': 14.669118165969849}
# Losses {'ner': 32.921215772628784}
# Losses {'ner': 51.32461929321289}
# Losses {'ner': 66.83781617879868}
# Losses {'ner': 84.58685845136642}
# Losses {'ner': 104.28553169965744}
# Losses {'ner': 118.69862872362137}
# Losses {'ner': 135.9071655869484}
# Losses {'ner': 141.68210025504231}
# Losses {'ner': 16.177379846572876}
# Losses {'ner': 27.81675097346306}
# Losses {'ner': 39.97793039679527}
# Losses {'ner': 61.868573039770126}
# Losses {'ner': 82.93745431303978}
# Losses {'ner': 98.74918994307518}
# Losses {'ner': 118.89779910445213}
# Losses {'ner': 137.386613458395}
# Losses {'ner': 140.94138318113983}
# Losses {'ner': 9.953585505485535}
# Losses {'ner': 23.033650040626526}
# Losses {'ner': 42.668296456336975}
# Losses {'ner': 62.29756152629852}
# Losses {'ner': 81.0762187242508}
# Losses {'ner': 97.33770620822906}
# Losses {'ner': 111.42478835582733}
# Losses {'ner': 130.56978058815002}
# Losses {'ner': 132.2926061525941}
# Losses {'ner': 17.972198486328125}
# Losses {'ner': 34.1584734916687}
# Losses {'ner': 52.42807078361511}
# Losses {'ner': 66.12364649772644}
# Losses {'ner': 83.70517361164093}
# Losses {'ner': 104.7803486585617}
# Losses {'ner': 120.73094153404236}
# Losses {'ner': 133.31400096416473}
# Losses {'ner': 138.1620842628181}
# Losses {'ner': 11.43316102027893}
# Losses {'ner': 29.352213144302368}
# Losses {'ner': 51.166316509246826}
# Losses {'ner': 67.06001305580139}
# Losses {'ner': 83.09898662567139}
# Losses {'ner': 107.57963252067566}
# Losses {'ner': 119.91250908374786}
# Losses {'ner': 138.97358405590057}
# Losses {'ner': 146.7781103849411}
# Losses {'ner': 15.96428632736206}
# Losses {'ner': 27.12071168422699}
# Losses {'ner': 49.840479254722595}
# Losses {'ner': 69.83368933200836}
# Losses {'ner': 92.06696140766144}
# Losses {'ner': 113.32609450817108}
# Losses {'ner': 127.80739623308182}
# Losses {'ner': 139.81551450490952}
# Losses {'ner': 145.0791847370565}
# Losses {'ner': 13.066860675811768}
# Losses {'ner': 30.864371180534363}
# Losses {'ner': 40.71891750395298}
# Losses {'ner': 56.655827060341835}
# Losses {'ner': 68.56251414120197}
# Losses {'ner': 87.95074684917927}
# Losses {'ner': 103.97394080460072}
# Losses {'ner': 118.3139775544405}
# Losses {'ner': 123.58088787458837}
# Losses {'ner': 15.716289043426514}
# Losses {'ner': 30.497820138931274}
# Losses {'ner': 49.862202644348145}
# Losses {'ner': 67.03144359588623}
# Losses {'ner': 79.8814731836319}
# Losses {'ner': 100.57408964633942}
# Losses {'ner': 121.08885943889618}
# Losses {'ner': 138.78767240047455}
# Losses {'ner': 144.7349574669497}
# Losses {'ner': 12.810141563415527}
# Losses {'ner': 28.014737129211426}
# Losses {'ner': 44.06545025110245}
# Losses {'ner': 68.99538832902908}
# Losses {'ner': 87.1523123383522}
# Losses {'ner': 101.55605465173721}
# Losses {'ner': 118.50922590494156}
# Losses {'ner': 129.37485855817795}
# Losses {'ner': 131.9599571498111}
# Losses {'ner': 23.44598364830017}
# Losses {'ner': 43.51535677909851}
# Losses {'ner': 58.3293274641037}
# Losses {'ner': 72.25550818443298}
# Losses {'ner': 82.94707643985748}
# Losses {'ner': 100.61310291290283}
# Losses {'ner': 120.32837867736816}
# Losses {'ner': 140.0783772468567}
# Losses {'ner': 144.14719755388796}
# Losses {'ner': 15.942807793617249}
# Losses {'ner': 37.49961197376251}
# Losses {'ner': 56.00952732563019}
# Losses {'ner': 68.31849482655525}
# Losses {'ner': 79.95865616202354}
# Losses {'ner': 101.31603941321373}
# Losses {'ner': 113.57075890898705}
# Losses {'ner': 122.6893001049757}
# Losses {'ner': 130.87135027348995}
# Losses {'ner': 24.235857009887695}
# Losses {'ner': 39.50341176986694}
# Losses {'ner': 54.35595202445984}
# Losses {'ner': 70.89480352401733}
# Losses {'ner': 84.79427945613861}
# Losses {'ner': 102.31822526454926}
# Losses {'ner': 116.50953447818756}
# Losses {'ner': 129.66214740276337}
# Losses {'ner': 133.15753214247525}
# Losses {'ner': 14.532557487487793}
# Losses {'ner': 32.519500970840454}
# Losses {'ner': 46.248740911483765}
# Losses {'ner': 64.2944847047329}
# Losses {'ner': 78.04926857352257}
# Losses {'ner': 96.28857144713402}
# Losses {'ner': 110.71600803732872}
# Losses {'ner': 128.32633623480797}
# Losses {'ner': 131.7979497127235}
# Losses {'ner': 22.471198081970215}
# Losses {'ner': 37.395328760147095}
# Losses {'ner': 52.74503839015961}
# Losses {'ner': 69.82615959644318}
# Losses {'ner': 84.4894469678402}
# Losses {'ner': 101.94769605994225}
# Losses {'ner': 114.02198895812035}
# Losses {'ner': 135.89621958136559}
# Losses {'ner': 140.65866534985253}
# Losses {'ner': 14.707647323608398}
# Losses {'ner': 32.691659569740295}
# Losses {'ner': 42.808855295181274}
# Losses {'ner': 55.256999135017395}
# Losses {'ner': 81.24294531345367}
# Losses {'ner': 90.40518911927938}
# Losses {'ner': 109.19322856515646}
# Losses {'ner': 129.6815114840865}
# Losses {'ner': 133.95710225834046}
# Losses {'ner': 21.325321912765503}
# Losses {'ner': 30.182553231716156}
# Losses {'ner': 47.70300906896591}
# Losses {'ner': 62.831288397312164}
# Losses {'ner': 80.60343366861343}
# Losses {'ner': 93.83600753545761}
# Losses {'ner': 109.1616033911705}
# Losses {'ner': 127.59977477788925}
# Losses {'ner': 131.42294004559517}
# Losses {'ner': 14.341064095497131}
# Losses {'ner': 27.524787962436676}
# Losses {'ner': 46.3498300909996}
# Losses {'ner': 65.74199885129929}
# Losses {'ner': 77.44146248698235}
# Losses {'ner': 95.90392538905144}
# Losses {'ner': 112.68447181582451}
# Losses {'ner': 129.9068474471569}
# Losses {'ner': 136.28841003775597}
# Losses {'ner': 14.231972217559814}
# Losses {'ner': 26.924570083618164}
# Losses {'ner': 37.89780569076538}
# Losses {'ner': 51.2351998090744}
# Losses {'ner': 66.31040441989899}
# Losses {'ner': 83.20778906345367}
# Losses {'ner': 102.34633243083954}
# Losses {'ner': 120.32473063468933}
# Losses {'ner': 126.73671662807465}
# Losses {'ner': 16.180283784866333}
# Losses {'ner': 30.28324246406555}
# Losses {'ner': 45.52817630767822}
# Losses {'ner': 62.58564853668213}
# Losses {'ner': 84.12976598739624}
# Losses {'ner': 100.62325859069824}
# Losses {'ner': 116.85837769508362}
# Losses {'ner': 127.54144167900085}
# Losses {'ner': 131.89660865068436}
# Losses {'ner': 15.48917007446289}
# Losses {'ner': 29.988317489624023}
# Losses {'ner': 43.70840835571289}
# Losses {'ner': 61.205625891685486}
# Losses {'ner': 83.30111491680145}
# Losses {'ner': 100.34840893745422}
# Losses {'ner': 118.94132447242737}
# Losses {'ner': 136.37467575073242}
# Losses {'ner': 141.7164399921894}
# Losses {'ner': 15.310002863407135}
# Losses {'ner': 32.15787035226822}
# Losses {'ner': 47.65503937005997}
# Losses {'ner': 64.07971793413162}
# Losses {'ner': 78.06763464212418}
# Losses {'ner': 96.74236541986465}
# Losses {'ner': 116.00231224298477}
# Losses {'ner': 128.18799224309623}
# Losses {'ner': 133.71737390570343}
# Losses {'ner': 9.773397028446198}
# Losses {'ner': 24.488310158252716}
# Losses {'ner': 40.64099270105362}
# Losses {'ner': 59.609690964221954}
# Losses {'ner': 74.2632959485054}
# Losses {'ner': 91.84683233499527}
# Losses {'ner': 110.74889069795609}
# Losses {'ner': 125.28523403406143}
# Losses {'ner': 129.64891999959946}
# Losses {'ner': 18.162551403045654}
# Losses {'ner': 33.32000291347504}
# Losses {'ner': 47.3029922246933}
# Losses {'ner': 59.36250424385071}
# Losses {'ner': 71.5575887709856}
# Losses {'ner': 95.9455658942461}
# Losses {'ner': 109.41110928356647}
# Losses {'ner': 125.6125410348177}
# Losses {'ner': 127.09036371298134}
# Losses {'ner': 11.205054998397827}
# Losses {'ner': 27.965514659881592}
# Losses {'ner': 40.62698447704315}
# Losses {'ner': 56.80064272880554}
# Losses {'ner': 71.35678720474243}
# Losses {'ner': 85.77765464782715}
# Losses {'ner': 106.12875390052795}
# Losses {'ner': 121.43455862998962}
# Losses {'ner': 125.58729575574398}
# Losses {'ner': 17.411603689193726}
# Losses {'ner': 33.740405559539795}
# Losses {'ner': 48.74706721305847}
# Losses {'ner': 66.22715735435486}
# Losses {'ner': 79.670643937774}
# Losses {'ner': 96.14262635726482}
# Losses {'ner': 121.49091131705791}
# Losses {'ner': 137.3705205442384}
# Losses {'ner': 142.77558982092887}
# Losses {'ner': 16.570480823516846}
# Losses {'ner': 36.61788749694824}
# Losses {'ner': 52.81636643409729}
# Losses {'ner': 72.53161263465881}
# Losses {'ner': 86.65733575820923}
# Losses {'ner': 106.92792987823486}
# Losses {'ner': 128.43746101856232}
# Losses {'ner': 140.13995736837387}
# Losses {'ner': 144.96355437487364}
# Losses {'ner': 19.857320308685303}
# Losses {'ner': 32.81188124418259}
# Losses {'ner': 48.64153426885605}
# Losses {'ner': 63.38829058408737}
# Losses {'ner': 80.66021543741226}
# Losses {'ner': 93.56582674384117}
# Losses {'ner': 112.09158483147621}
# Losses {'ner': 129.0881933271885}
# Losses {'ner': 134.4245696514845}
# Losses {'ner': 16.05664300918579}
# Losses {'ner': 23.59863781929016}
# Losses {'ner': 35.428940534591675}
# Losses {'ner': 50.19754076004028}
# Losses {'ner': 66.11121642589569}
# Losses {'ner': 86.76185929775238}
# Losses {'ner': 95.72827017307281}
# Losses {'ner': 110.91402399539948}
# Losses {'ner': 116.01494359970093}
# Losses {'ner': 19.046921968460083}
# Losses {'ner': 36.25415563583374}
# Losses {'ner': 54.58378028869629}
# Losses {'ner': 69.36063933372498}
# Losses {'ner': 86.49048519134521}
# Losses {'ner': 98.6777081489563}
# Losses {'ner': 114.07669305801392}
# Losses {'ner': 126.08839756250381}
# Losses {'ner': 131.70812799036503}
# Losses {'ner': 13.268267393112183}
# Losses {'ner': 27.948156237602234}
# Losses {'ner': 47.382665276527405}
# Losses {'ner': 61.01171088218689}
# Losses {'ner': 76.46668410301208}
# Losses {'ner': 97.49275255203247}
# Losses {'ner': 122.55644869804382}
# Losses {'ner': 134.94051110744476}
# Losses {'ner': 137.06834474549396}
# Losses {'ner': 13.931799411773682}
# Losses {'ner': 30.655376970767975}
# Losses {'ner': 50.40749555826187}
# Losses {'ner': 66.65467554330826}
# Losses {'ner': 82.33885020017624}
# Losses {'ner': 95.65936607122421}
# Losses {'ner': 116.09419816732407}
# Losses {'ner': 134.81694334745407}
# Losses {'ner': 140.1210836172104}
# Losses {'ner': 16.780628561973572}
# Losses {'ner': 28.73683173954487}
# Losses {'ner': 45.13045294582844}
# Losses {'ner': 58.72887296974659}
# Losses {'ner': 73.60552163422108}
# Losses {'ner': 84.80044765770435}
# Losses {'ner': 98.51140387356281}
# Losses {'ner': 114.57677395641804}
# Losses {'ner': 115.93087234348059}
# Losses {'ner': 13.238032341003418}
# Losses {'ner': 25.909340023994446}
# Losses {'ner': 40.107324719429016}
# Losses {'ner': 56.539021134376526}
# Losses {'ner': 72.25453412532806}
# Losses {'ner': 85.58437752723694}
# Losses {'ner': 104.99977564811707}
# Losses {'ner': 122.29997491836548}
# Losses {'ner': 129.64014068245888}
# Losses {'ner': 11.591535210609436}
# Losses {'ner': 24.799370884895325}
# Losses {'ner': 41.520790696144104}
# Losses {'ner': 62.21382033824921}
# Losses {'ner': 77.12611627578735}
# Losses {'ner': 92.11394584178925}
# Losses {'ner': 107.85860455036163}
# Losses {'ner': 126.84199059009552}
# Losses {'ner': 132.06135529330464}
# Losses {'ner': 19.312684297561646}
# Losses {'ner': 33.32294940948486}
# Losses {'ner': 47.05845630168915}
# Losses {'ner': 62.15617048740387}
# Losses {'ner': 83.98125374317169}
# Losses {'ner': 100.13095557689667}
# Losses {'ner': 114.45845460891724}
# Losses {'ner': 131.0247038602829}
# Losses {'ner': 135.19826060533524}
# Losses {'ner': 14.099278688430786}
# Losses {'ner': 28.859851360321045}
# Losses {'ner': 47.98644542694092}
# Losses {'ner': 65.54913640022278}
# Losses {'ner': 84.52673363685608}
# Losses {'ner': 98.2836184501648}
# Losses {'ner': 115.09285616874695}
# Losses {'ner': 129.84441494941711}
# Losses {'ner': 133.3787797689438}
# Losses {'ner': 19.060567140579224}
# Losses {'ner': 35.23713856935501}
# Losses {'ner': 47.406297862529755}
# Losses {'ner': 61.6064378619194}
# Losses {'ner': 71.88646495342255}
# Losses {'ner': 81.9718137383461}
# Losses {'ner': 101.38857418298721}
# Losses {'ner': 114.3523297905922}
# Losses {'ner': 116.68024411052465}
# Losses {'ner': 12.311602711677551}
# Losses {'ner': 28.915131449699402}
# Losses {'ner': 46.048708319664}
# Losses {'ner': 56.977516531944275}
# Losses {'ner': 72.36310660839081}
# Losses {'ner': 95.8167051076889}
# Losses {'ner': 110.1306791305542}
# Losses {'ner': 120.11420315504074}
# Losses {'ner': 126.22332821786404}
# Losses {'ner': 10.795280739665031}
# Losses {'ner': 24.04332274198532}
# Losses {'ner': 45.346363961696625}
# Losses {'ner': 57.94991511106491}
# Losses {'ner': 72.54705983400345}
# Losses {'ner': 86.4399362206459}
# Losses {'ner': 96.39760917425156}
# Losses {'ner': 119.38341182470322}
# Losses {'ner': 123.10887258686125}
# Losses {'ner': 12.02747666835785}
# Losses {'ner': 23.111684679985046}
# Losses {'ner': 34.62281060218811}
# Losses {'ner': 47.96358406543732}
# Losses {'ner': 61.0688271522522}
# Losses {'ner': 76.29965996742249}
# Losses {'ner': 92.14764153957367}
# Losses {'ner': 107.24921464920044}
# Losses {'ner': 108.33732835715637}
# Losses {'ner': 26.51201295852661}
# Losses {'ner': 43.697317600250244}
# Losses {'ner': 55.752787470817566}
# Losses {'ner': 72.70206892490387}
# Losses {'ner': 85.14849591255188}
# Losses {'ner': 94.80886697769165}
# Losses {'ner': 107.86800718307495}
# Losses {'ner': 119.3524340391159}
# Losses {'ner': 121.87778491573408}
# Losses {'ner': 12.037308931350708}
# Losses {'ner': 33.41812872886658}
# Losses {'ner': 57.44070386886597}
# Losses {'ner': 72.58922743797302}
# Losses {'ner': 89.97851967811584}
# Losses {'ner': 99.54139268398285}
# Losses {'ner': 111.8970547914505}
# Losses {'ner': 123.74041152000427}
# Losses {'ner': 125.4722447108943}
# Losses {'ner': 16.17515754699707}
# Losses {'ner': 28.16919434070587}
# Losses {'ner': 46.93585288524628}
# Losses {'ner': 61.81066691875458}
# Losses {'ner': 78.07188308238983}
# Losses {'ner': 92.80469787120819}
# Losses {'ner': 114.59976637363434}
# Losses {'ner': 127.8059561252594}
# Losses {'ner': 131.44537395238876}
# Losses {'ner': 11.925333023071289}
# Losses {'ner': 26.9085373878479}
# Losses {'ner': 40.63525187969208}
# Losses {'ner': 63.63354694843292}
# Losses {'ner': 73.80593174695969}
# Losses {'ner': 86.61245983839035}
# Losses {'ner': 102.42248839139938}
# Losses {'ner': 116.47720974683762}
# Losses {'ner': 118.01879573985934}
# Losses {'ner': 10.12349933385849}
# Losses {'ner': 24.93303209543228}
# Losses {'ner': 39.96148496866226}
# Losses {'ner': 56.713506281375885}
# Losses {'ner': 76.83663731813431}
# Losses {'ner': 91.73274558782578}
# Losses {'ner': 106.10772317647934}
# Losses {'ner': 129.5722820162773}
# Losses {'ner': 135.66405683755875}
# Losses {'ner': 15.42179000377655}
# Losses {'ner': 28.069268822669983}
# Losses {'ner': 40.313910603523254}
# Losses {'ner': 57.62683618068695}
# Losses {'ner': 75.94544160366058}
# Losses {'ner': 90.49688827991486}
# Losses {'ner': 103.15141451358795}
# Losses {'ner': 115.43067991733551}
# Losses {'ner': 119.3134870827198}
# Losses {'ner': 11.222997307777405}
# Losses {'ner': 23.919658422470093}
# Losses {'ner': 40.97913348674774}
# Losses {'ner': 55.40484690666199}
# Losses {'ner': 71.06558060646057}
# Losses {'ner': 89.05086398124695}
# Losses {'ner': 105.10904633998871}
# Losses {'ner': 119.86385142803192}
# Losses {'ner': 125.58967196941376}
# Losses {'ner': 15.957623720169067}
# Losses {'ner': 36.043858766555786}
# Losses {'ner': 50.602733969688416}
# Losses {'ner': 66.21103227138519}
# Losses {'ner': 83.42213785648346}
# Losses {'ner': 95.59520502015948}
# Losses {'ner': 110.89238352701068}
# Losses {'ner': 125.38670940324664}
# Losses {'ner': 131.36978251859546}
# Losses {'ner': 16.394310474395752}
# Losses {'ner': 30.686645030975342}
# Losses {'ner': 47.0781455039978}
# Losses {'ner': 60.00954473018646}
# Losses {'ner': 76.32557737827301}
# Losses {'ner': 96.04164803028107}
# Losses {'ner': 109.49151957035065}
# Losses {'ner': 121.09593769162893}
# Losses {'ner': 122.81439376622438}
# Losses {'ner': 12.641920566558838}
# Losses {'ner': 29.551812410354614}
# Losses {'ner': 43.82897424697876}
# Losses {'ner': 58.51537263393402}
# Losses {'ner': 78.20905721187592}
# Losses {'ner': 89.72795712947845}
# Losses {'ner': 108.14687693119049}
# Losses {'ner': 126.36773383617401}
# Losses {'ner': 130.73684746026993}
# Losses {'ner': 12.459863305091858}
# Losses {'ner': 28.749914050102234}
# Losses {'ner': 38.51320159435272}
# Losses {'ner': 51.06183111667633}
# Losses {'ner': 66.12652158737183}
# Losses {'ner': 77.57812786102295}
# Losses {'ner': 96.37779116630554}
# Losses {'ner': 113.97639966011047}
# Losses {'ner': 119.21051459014416}
# Losses {'ner': 11.861371278762817}
# Losses {'ner': 27.933507919311523}
# Losses {'ner': 41.35626935958862}
# Losses {'ner': 59.78751277923584}
# Losses {'ner': 73.0163232088089}
# Losses {'ner': 90.63109838962555}
# Losses {'ner': 100.50769686698914}
# Losses {'ner': 117.98138976097107}
# Losses {'ner': 121.0659197345376}
# Losses {'ner': 17.745457649230957}
# Losses {'ner': 37.51108264923096}
# Losses {'ner': 51.08255732059479}
# Losses {'ner': 68.26303851604462}
# Losses {'ner': 85.96170604228973}
# Losses {'ner': 101.46958899497986}
# Losses {'ner': 114.1326425075531}
# Losses {'ner': 128.70828956365585}
# Losses {'ner': 131.88331737928092}
# Losses {'ner': 11.012832999229431}
# Losses {'ner': 26.845999836921692}
# Losses {'ner': 42.76497781276703}
# Losses {'ner': 57.21700942516327}
# Losses {'ner': 76.82389986515045}
# Losses {'ner': 87.87726032733917}
# Losses {'ner': 104.60587644577026}
# Losses {'ner': 120.895578622818}
# Losses {'ner': 127.26513111591339}
# Losses {'ner': 15.828521609306335}
# Losses {'ner': 30.363571286201477}
# Losses {'ner': 46.287561535835266}
# Losses {'ner': 63.90692365169525}
# Losses {'ner': 81.06420814990997}
# Losses {'ner': 95.12132585048676}
# Losses {'ner': 108.18426132202148}
# Losses {'ner': 123.75235331058502}
# Losses {'ner': 126.56159538030624}
# Losses {'ner': 15.051153421401978}
# Losses {'ner': 27.494009137153625}
# Losses {'ner': 42.478450298309326}
# Losses {'ner': 57.18491005897522}
# Losses {'ner': 70.90716624259949}
# Losses {'ner': 86.10388541221619}
# Losses {'ner': 100.80671858787537}
# Losses {'ner': 118.79891729354858}
# Losses {'ner': 126.78255159314722}
# Losses {'ner': 14.775912165641785}
# Losses {'ner': 28.741791367530823}
# Losses {'ner': 43.573906660079956}
# Losses {'ner': 64.70556211471558}
# Losses {'ner': 79.92855095863342}
# Losses {'ner': 95.70448994636536}
# Losses {'ner': 105.17366659641266}
# Losses {'ner': 124.246373295784}
# Losses {'ner': 126.78184734402012}
# Losses {'ner': 7.373767018318176}
# Losses {'ner': 27.531890988349915}
# Losses {'ner': 46.332223534584045}
# Losses {'ner': 57.73898100852966}
# Losses {'ner': 70.02305269241333}
# Losses {'ner': 81.68754303455353}
# Losses {'ner': 93.2932094335556}
# Losses {'ner': 114.01209628582001}
# Losses {'ner': 117.15106153488159}
# Losses {'ner': 15.119675993919373}
# Losses {'ner': 29.73305380344391}
# Losses {'ner': 46.05601966381073}
# Losses {'ner': 64.03989589214325}
# Losses {'ner': 82.6338700056076}
# Losses {'ner': 96.3006500005722}
# Losses {'ner': 108.12115186452866}
# Losses {'ner': 125.19972628355026}
# Losses {'ner': 128.40875095129013}
# Losses {'ner': 12.575886964797974}
# Losses {'ner': 30.088223814964294}
# Losses {'ner': 45.12059569358826}
# Losses {'ner': 59.37918734550476}
# Losses {'ner': 77.35050368309021}
# Losses {'ner': 90.64915013313293}
# Losses {'ner': 103.319580078125}
# Losses {'ner': 114.81521260738373}
# Losses {'ner': 118.69929350167513}
# Losses {'ner': 12.579320192337036}
# Losses {'ner': 28.66132140159607}
# Losses {'ner': 48.432727098464966}
# Losses {'ner': 62.114309906959534}
# Losses {'ner': 83.94866955280304}
# Losses {'ner': 96.2098103761673}
# Losses {'ner': 114.38505375385284}
# Losses {'ner': 125.84665131568909}
# Losses {'ner': 127.38450016826391}
# Losses {'ner': 15.582809448242188}
# Losses {'ner': 30.32295846939087}
# Losses {'ner': 49.92485046386719}
# Losses {'ner': 62.560158491134644}
# Losses {'ner': 79.52041792869568}
# Losses {'ner': 95.22483921051025}
# Losses {'ner': 110.35137557983398}
# Losses {'ner': 122.33657824993134}
# Losses {'ner': 126.13794823735952}
# Losses {'ner': 17.352083444595337}
# Losses {'ner': 35.29086756706238}
# Losses {'ner': 50.14996862411499}
# Losses {'ner': 65.07322645187378}
# Losses {'ner': 85.67254495620728}
# Losses {'ner': 96.94357228279114}
# Losses {'ner': 113.66659641265869}
# Losses {'ner': 133.8881754875183}
# Losses {'ner': 135.86420900933444}
# Losses {'ner': 8.988033413887024}
# Losses {'ner': 20.438703954219818}
# Losses {'ner': 35.5761404633522}
# Losses {'ner': 53.30105572938919}
# Losses {'ner': 71.3837953209877}
# Losses {'ner': 86.64449101686478}
# Losses {'ner': 98.92357522249222}
# Losses {'ner': 110.31831365823746}
# Losses {'ner': 113.698339586379}
# Losses {'ner': 15.353104948997498}
# Losses {'ner': 31.359544157981873}
# Losses {'ner': 49.50374257564545}
# Losses {'ner': 66.89534771442413}
# Losses {'ner': 84.59167158603668}
# Losses {'ner': 101.09448063373566}
# Losses {'ner': 114.13921463489532}
# Losses {'ner': 130.03301537036896}
# Losses {'ner': 135.31707763671875}
# Losses {'ner': 19.540175914764404}
# Losses {'ner': 35.32389688491821}
# Losses {'ner': 53.381224513053894}
# Losses {'ner': 66.64776337146759}
# Losses {'ner': 85.62362563610077}
# Losses {'ner': 94.45674002170563}
# Losses {'ner': 110.83405876159668}
# Losses {'ner': 123.62140536308289}
# Losses {'ner': 124.06217969569855}
# Losses {'ner': 15.069935321807861}
# Losses {'ner': 30.4384548664093}
# Losses {'ner': 47.030418395996094}
# Losses {'ner': 60.73709559440613}
# Losses {'ner': 76.79912829399109}
# Losses {'ner': 93.2388527393341}
# Losses {'ner': 111.31383919715881}
# Losses {'ner': 130.02588033676147}
# Losses {'ner': 135.0453460663557}
# Losses {'ner': 12.702845573425293}
# Losses {'ner': 33.587791442871094}
# Losses {'ner': 47.385260820388794}
# Losses {'ner': 59.10136079788208}
# Losses {'ner': 76.54949069023132}
# Losses {'ner': 93.22060185670853}
# Losses {'ner': 110.16390627622604}
# Losses {'ner': 119.89617985486984}
# Losses {'ner': 126.71786080417223}
# Losses {'ner': 17.182926416397095}
# Losses {'ner': 35.967804193496704}
# Losses {'ner': 58.82665681838989}
# Losses {'ner': 72.556232213974}
# Losses {'ner': 85.55553758144379}
# Losses {'ner': 100.12220966815948}
# Losses {'ner': 109.69006311893463}
# Losses {'ner': 125.89169430732727}
# Losses {'ner': 128.9507296346128}
# Losses {'ner': 14.244088172912598}
# Losses {'ner': 31.02613115310669}
# Losses {'ner': 47.61073303222656}
# Losses {'ner': 57.907705426216125}
# Losses {'ner': 76.78983509540558}
# Losses {'ner': 94.41483891010284}
# Losses {'ner': 107.54684257507324}
# Losses {'ner': 120.77293622493744}
# Losses {'ner': 123.20139745995402}
# Losses {'ner': 14.729331493377686}
# Losses {'ner': 29.282756090164185}
# Losses {'ner': 43.86652493476868}
# Losses {'ner': 57.91301608085632}
# Losses {'ner': 79.44714379310608}
# Losses {'ner': 93.88830709457397}
# Losses {'ner': 103.2839742898941}
# Losses {'ner': 116.4498610496521}
# Losses {'ner': 120.70042765140533}
# Losses {'ner': 12.48693323135376}
# Losses {'ner': 26.060827255249023}
# Losses {'ner': 44.85690689086914}
# Losses {'ner': 60.724583864212036}
# Losses {'ner': 72.65509867668152}
# Losses {'ner': 87.20421755313873}
# Losses {'ner': 100.2722932100296}
# Losses {'ner': 113.98697245121002}
# Losses {'ner': 115.59943614969961}
# Losses {'ner': 17.798519730567932}
# Losses {'ner': 32.954585909843445}
# Losses {'ner': 48.79915511608124}
# Losses {'ner': 60.40937602519989}
# Losses {'ner': 76.47168719768524}
# Losses {'ner': 93.59323847293854}
# Losses {'ner': 112.97875440120697}
# Losses {'ner': 123.46978931501508}
# Losses {'ner': 124.52145960288908}
# Losses {'ner': 17.87980604171753}
# Losses {'ner': 33.85101890563965}
# Losses {'ner': 50.54794228076935}
# Losses {'ner': 62.24232304096222}
# Losses {'ner': 76.85420191287994}
# Losses {'ner': 94.89795792102814}
# Losses {'ner': 109.06170165538788}
# Losses {'ner': 122.958456158638}
# Losses {'ner': 129.50296771526337}
# Losses {'ner': 11.349107682704926}
# Losses {'ner': 18.62099438905716}
# Losses {'ner': 29.785530745983124}
# Losses {'ner': 45.98574870824814}
# Losses {'ner': 61.21765869855881}
# Losses {'ner': 73.51324528455734}
# Losses {'ner': 92.63663667440414}
# Losses {'ner': 112.36789411306381}
# Losses {'ner': 116.51644903118722}
# Losses {'ner': 15.785345792770386}
# Losses {'ner': 28.6535484790802}
# Losses {'ner': 51.39430785179138}
# Losses {'ner': 60.29499393701553}
# Losses {'ner': 71.27019947767258}
# Losses {'ner': 84.01028591394424}
# Losses {'ner': 104.46371704339981}
# Losses {'ner': 119.0102441906929}
# Losses {'ner': 123.99314506351948}
# Losses {'ner': 14.76297414302826}
# Losses {'ner': 26.968343377113342}
# Losses {'ner': 40.10062897205353}
# Losses {'ner': 62.006107687950134}
# Losses {'ner': 76.63189041614532}
# Losses {'ner': 90.17979753017426}
# Losses {'ner': 107.42411077022552}
# Losses {'ner': 119.72088050842285}
# Losses {'ner': 122.35346558093443}
# Losses {'ner': 16.41775131225586}
# Losses {'ner': 25.80512571334839}
# Losses {'ner': 39.52611291408539}
# Losses {'ner': 58.070446848869324}
# Losses {'ner': 72.1506826877594}
# Losses {'ner': 85.06934106349945}
# Losses {'ner': 106.2612966299057}
# Losses {'ner': 118.77806770801544}
# Losses {'ner': 123.12356263399124}
# Losses {'ner': 14.046324849128723}
# Losses {'ner': 22.954594030976295}
# Losses {'ner': 38.81432594358921}
# Losses {'ner': 56.46154345571995}
# Losses {'ner': 72.29052199423313}
# Losses {'ner': 89.81801237165928}
# Losses {'ner': 103.12316550314426}
# Losses {'ner': 119.0350724607706}
# Losses {'ner': 122.16564805805683}
# Losses {'ner': 19.64208698272705}
# Losses {'ner': 32.280919551849365}
# Losses {'ner': 44.781054973602295}
# Losses {'ner': 57.856759905815125}
# Losses {'ner': 74.13315975666046}
# Losses {'ner': 87.98115241527557}
# Losses {'ner': 107.4954365491867}
# Losses {'ner': 119.51525270938873}
# Losses {'ner': 119.84790617602425}
# Losses {'ner': 17.02978754043579}
# Losses {'ner': 28.800752997398376}
# Losses {'ner': 46.411282658576965}
# Losses {'ner': 60.471213936805725}
# Losses {'ner': 70.65252208709717}
# Losses {'ner': 90.00731444358826}
# Losses {'ner': 107.79861259460449}
# Losses {'ner': 125.30134654045105}
# Losses {'ner': 127.2519691423513}
# Losses {'ner': 13.894106149673462}
# Losses {'ner': 29.894608080387115}
# Losses {'ner': 42.82450321316719}
# Losses {'ner': 60.32402613759041}
# Losses {'ner': 79.3682589828968}
# Losses {'ner': 89.64922249317169}
# Losses {'ner': 101.4112879037857}
# Losses {'ner': 116.07412934303284}
# Losses {'ner': 119.88113335554954}
# Losses {'ner': 18.624621272087097}
# Losses {'ner': 30.60958445072174}
# Losses {'ner': 48.81309926509857}
# Losses {'ner': 61.50659430027008}
# Losses {'ner': 72.29220378398895}
# Losses {'ner': 93.68524491786957}
# Losses {'ner': 109.88738405704498}
# Losses {'ner': 126.62672507762909}
# Losses {'ner': 127.09177470183931}
# Losses {'ner': 13.569640874862671}
# Losses {'ner': 31.68279528617859}
# Losses {'ner': 39.13120496273041}
# Losses {'ner': 53.72061562538147}
# Losses {'ner': 67.26551067829132}
# Losses {'ner': 81.01742178201675}
# Losses {'ner': 97.23886567354202}
# Losses {'ner': 114.77448755502701}
# Losses {'ner': 119.52071279287338}
# Losses {'ner': 14.96791958808899}
# Losses {'ner': 28.43919375538826}
# Losses {'ner': 42.473932296037674}
# Losses {'ner': 61.13727334141731}
# Losses {'ner': 73.61138358712196}
# Losses {'ner': 89.31660190224648}
# Losses {'ner': 103.50756326317787}
# Losses {'ner': 117.9710513651371}
# Losses {'ner': 121.06860484334175}
# Losses {'ner': 15.353098034858704}
# Losses {'ner': 30.60857093334198}
# Losses {'ner': 52.21916425228119}
# Losses {'ner': 64.64997184276581}
# Losses {'ner': 76.01674818992615}
# Losses {'ner': 96.95134282112122}
# Losses {'ner': 107.10905867815018}
# Losses {'ner': 126.00011521577835}
# Losses {'ner': 130.26825523376465}
# Losses {'ner': 17.82291078567505}
# Losses {'ner': 28.65598303079605}
# Losses {'ner': 42.8266527056694}
# Losses {'ner': 55.899939477443695}
# Losses {'ner': 70.08067506551743}
# Losses {'ner': 89.94697326421738}
# Losses {'ner': 106.36124294996262}
# Losses {'ner': 120.50696295499802}
# Losses {'ner': 123.48468195274472}
# Losses {'ner': 12.711157083511353}
# Losses {'ner': 24.049454867839813}
# Losses {'ner': 38.56578749418259}
# Losses {'ner': 54.73531764745712}
# Losses {'ner': 67.08658522367477}
# Losses {'ner': 81.7117149233818}
# Losses {'ner': 97.82553166151047}
# Losses {'ner': 110.35355335474014}
# Losses {'ner': 116.15195977687836}
# Losses {'ner': 12.904576539993286}
# Losses {'ner': 26.107874393463135}
# Losses {'ner': 43.49409079551697}
# Losses {'ner': 57.18931019306183}
# Losses {'ner': 75.72605288028717}
# Losses {'ner': 88.22748672962189}
# Losses {'ner': 101.538694024086}
# Losses {'ner': 114.61214482784271}
# Losses {'ner': 122.15696746110916}
# Losses {'ner': 14.316236138343811}
# Losses {'ner': 30.872081875801086}
# Losses {'ner': 46.56626737117767}
# Losses {'ner': 62.33853375911713}
# Losses {'ner': 77.43339049816132}
# Losses {'ner': 87.48389601707458}
# Losses {'ner': 101.02285313606262}
# Losses {'ner': 122.10317993164062}
# Losses {'ner': 127.64650028944016}
# Losses {'ner': 17.6995849609375}
# Losses {'ner': 29.07633686065674}
# Losses {'ner': 42.21158003807068}
# Losses {'ner': 54.233521580696106}
# Losses {'ner': 69.94064629077911}
# Losses {'ner': 81.8429045677185}
# Losses {'ner': 98.80488204956055}
# Losses {'ner': 109.08000337495469}
# Losses {'ner': 110.14607259601598}
# Losses {'ner': 18.08816695213318}
# Losses {'ner': 33.15165829658508}
# Losses {'ner': 45.36617636680603}
# Losses {'ner': 62.28627789020538}
# Losses {'ner': 83.8346608877182}
# Losses {'ner': 98.21311944723129}
# Losses {'ner': 108.37522637844086}
# Losses {'ner': 126.64535820484161}
# Losses {'ner': 130.01777248084545}
# Losses {'ner': 17.716657876968384}
# Losses {'ner': 35.185945987701416}
# Losses {'ner': 46.63321137428284}
# Losses {'ner': 63.738983035087585}
# Losses {'ner': 78.82076680660248}
# Losses {'ner': 91.87769949436188}
# Losses {'ner': 102.57709753513336}
# Losses {'ner': 115.29208076000214}
# Losses {'ner': 120.08063305966789}
# Losses {'ner': 14.372021675109863}
# Losses {'ner': 30.21776032447815}
# Losses {'ner': 40.245272159576416}
# Losses {'ner': 47.47313278913498}
# Losses {'ner': 60.943009078502655}
# Losses {'ner': 73.99384397268295}
# Losses {'ner': 87.13069957494736}
# Losses {'ner': 101.42599231004715}
# Losses {'ner': 104.94841879606247}
# Losses {'ner': 17.524543285369873}
# Losses {'ner': 33.718504905700684}
# Losses {'ner': 46.13829064369202}
# Losses {'ner': 58.92093026638031}
# Losses {'ner': 69.43171274662018}
# Losses {'ner': 89.23565423488617}
# Losses {'ner': 100.36149215698242}
# Losses {'ner': 115.03047943115234}
# Losses {'ner': 119.56233739852905}
# Losses {'ner': 14.2033371925354}
# Losses {'ner': 26.571110606193542}
# Losses {'ner': 41.63443207740784}
# Losses {'ner': 56.07988178730011}
# Losses {'ner': 77.45555937290192}
# Losses {'ner': 94.56247770786285}
# Losses {'ner': 111.80606293678284}
# Losses {'ner': 127.6144688129425}
# Losses {'ner': 131.42212715626079}
# Losses {'ner': 15.259414911270142}
# Losses {'ner': 34.09306764602661}
# Losses {'ner': 45.07696223258972}
# Losses {'ner': 58.88415884971619}
# Losses {'ner': 77.18348360061646}
# Losses {'ner': 89.98295950889587}
# Losses {'ner': 106.66235446929932}
# Losses {'ner': 118.84934747219086}
# Losses {'ner': 122.68382083285542}
# Losses {'ner': 16.180593490600586}
# Losses {'ner': 27.3837867975235}
# Losses {'ner': 40.87275767326355}
# Losses {'ner': 62.42681407928467}
# Losses {'ner': 82.36560583114624}
# Losses {'ner': 93.87601816654205}
# Losses {'ner': 104.35922729969025}
# Losses {'ner': 119.67949211597443}
# Losses {'ner': 125.3570908755064}
# Losses {'ner': 11.701390862464905}
# Losses {'ner': 28.22367525100708}
# Losses {'ner': 44.07214283943176}
# Losses {'ner': 57.746164321899414}
# Losses {'ner': 69.00256376969628}
# Losses {'ner': 86.22213822114281}
# Losses {'ner': 98.48148840176873}
# Losses {'ner': 117.8520166228991}
# Losses {'ner': 121.89283985389193}
# Losses {'ner': 17.83664035797119}
# Losses {'ner': 35.98806691169739}
# Losses {'ner': 51.057776927948}
# Losses {'ner': 69.77709978818893}
# Losses {'ner': 85.94514030218124}
# Losses {'ner': 102.23853605985641}
# Losses {'ner': 119.10318630933762}
# Losses {'ner': 132.23351782560349}
# Losses {'ner': 132.95495135878446}
# Losses {'ner': 12.21181333065033}
# Losses {'ner': 24.95451056957245}
# Losses {'ner': 45.68953549861908}
# Losses {'ner': 64.82803237438202}
# Losses {'ner': 83.50524532794952}
# Losses {'ner': 96.69410514831543}
# Losses {'ner': 116.01542854309082}
# Losses {'ner': 126.96258145570755}
# Losses {'ner': 128.91574213281274}
# Losses {'ner': 15.865402698516846}
# Losses {'ner': 29.611343383789062}
# Losses {'ner': 42.27108705043793}
# Losses {'ner': 61.89382064342499}
# Losses {'ner': 72.16165566444397}
# Losses {'ner': 90.15424013137817}
# Losses {'ner': 104.83998489379883}
# Losses {'ner': 117.45357501506805}
# Losses {'ner': 119.743443319574}
# Losses {'ner': 9.477191150188446}
# Losses {'ner': 21.38817048072815}
# Losses {'ner': 37.5960738658905}
# Losses {'ner': 50.115217328071594}
# Losses {'ner': 67.31159913539886}
# Losses {'ner': 84.26285922527313}
# Losses {'ner': 104.76101815700531}
# Losses {'ner': 121.37449514865875}
# Losses {'ner': 123.98008993268013}
# Losses {'ner': 16.306836485862732}
# Losses {'ner': 33.97583734989166}
# Losses {'ner': 47.56967496871948}
# Losses {'ner': 62.380080461502075}
# Losses {'ner': 80.51327061653137}
# Losses {'ner': 94.84778141975403}
# Losses {'ner': 113.21551632881165}
# Losses {'ner': 127.95799648761749}
# Losses {'ner': 133.0830473601818}
# Losses {'ner': 20.966699361801147}
# Losses {'ner': 31.590291738510132}
# Losses {'ner': 46.24636244773865}
# Losses {'ner': 61.31901979446411}
# Losses {'ner': 76.40177750587463}
# Losses {'ner': 92.78107726573944}
# Losses {'ner': 102.67848706245422}
# Losses {'ner': 118.34091019630432}
# Losses {'ner': 121.00987621193053}
# Losses {'ner': 16.00402855873108}
# Losses {'ner': 32.33174932003021}
# Losses {'ner': 46.35784065723419}
# Losses {'ner': 64.25097811222076}
# Losses {'ner': 76.16277825832367}
# Losses {'ner': 85.47220480442047}
# Losses {'ner': 104.94945800304413}
# Losses {'ner': 119.45717370510101}
# Losses {'ner': 122.82834379177075}
# Losses {'ner': 13.689486980438232}
# Losses {'ner': 25.124517679214478}
# Losses {'ner': 41.251227378845215}
# Losses {'ner': 54.93766647577286}
# Losses {'ner': 72.13075286149979}
# Losses {'ner': 83.65177130699158}
# Losses {'ner': 90.35591334104538}
# Losses {'ner': 110.48731154203415}
# Losses {'ner': 112.43250356434328}
# Losses {'ner': 19.650148153305054}
# Losses {'ner': 30.607434391975403}
# Losses {'ner': 46.62102401256561}
# Losses {'ner': 62.206793546676636}
# Losses {'ner': 80.12737274169922}
# Losses {'ner': 97.93612885475159}
# Losses {'ner': 109.79661214351654}
# Losses {'ner': 128.10777533054352}
# Losses {'ner': 130.59872470796108}
# Losses {'ner': 14.467707753181458}
# Losses {'ner': 30.580862164497375}
# Losses {'ner': 43.71553027629852}
# Losses {'ner': 58.74126899242401}
# Losses {'ner': 74.70791864395142}
# Losses {'ner': 91.31375181674957}
# Losses {'ner': 107.53862082958221}
# Losses {'ner': 122.84852921962738}
# Losses {'ner': 128.56279921531677}
# Losses {'ner': 14.247688293457031}
# Losses {'ner': 31.118580102920532}
# Losses {'ner': 46.66253638267517}
# Losses {'ner': 59.340946316719055}
# Losses {'ner': 70.30022084712982}
# Losses {'ner': 85.0289169549942}
# Losses {'ner': 102.29043006896973}
# Losses {'ner': 111.98352122306824}
# Losses {'ner': 118.91385760903358}
# Losses {'ner': 13.966248869895935}
# Losses {'ner': 29.15344226360321}
# Losses {'ner': 41.78246092796326}
# Losses {'ner': 55.19100308418274}
# Losses {'ner': 73.06342768669128}
# Losses {'ner': 88.64220666885376}
# Losses {'ner': 100.12612342834473}
# Losses {'ner': 122.46127152442932}
# Losses {'ner': 126.05232151597738}
# Losses {'ner': 15.064866542816162}
# Losses {'ner': 30.396294593811035}
# Losses {'ner': 44.41181707382202}
# Losses {'ner': 63.46682333946228}
# Losses {'ner': 77.14501488208771}
# Losses {'ner': 94.2034159898758}
# Losses {'ner': 107.04789888858795}
# Losses {'ner': 121.0114666223526}
# Losses {'ner': 125.60928247579432}
# Losses {'ner': 18.00632095336914}
# Losses {'ner': 37.333635330200195}
# Losses {'ner': 49.73767304420471}
# Losses {'ner': 62.377961814403534}
# Losses {'ner': 78.97058552503586}
# Losses {'ner': 87.5511035323143}
# Losses {'ner': 105.18290609121323}
# Losses {'ner': 118.74718517065048}
# Losses {'ner': 124.1522181481123}
# Losses {'ner': 21.835686206817627}
# Losses {'ner': 39.53762173652649}
# Losses {'ner': 49.03366947174072}
# Losses {'ner': 65.013214468956}
# Losses {'ner': 77.67525434494019}
# Losses {'ner': 91.59430885314941}
# Losses {'ner': 105.00638222694397}
# Losses {'ner': 124.34535622596741}
# Losses {'ner': 130.89337182044983}
# Losses {'ner': 10.402071714401245}
# Losses {'ner': 27.244369745254517}
# Losses {'ner': 42.88310134410858}
# Losses {'ner': 59.80175805091858}
# Losses {'ner': 78.5816102027893}
# Losses {'ner': 95.16988730430603}
# Losses {'ner': 108.23584055900574}
# Losses {'ner': 119.17783737182617}
# Losses {'ner': 125.1114884018898}
# Losses {'ner': 11.452495783567429}
# Losses {'ner': 24.87206956744194}
# Losses {'ner': 40.37078043818474}
# Losses {'ner': 55.44615909457207}
# Losses {'ner': 64.79629012942314}
# Losses {'ner': 82.58860191702843}
# Losses {'ner': 89.52412351965904}
# Losses {'ner': 111.54715260863304}
# Losses {'ner': 116.1103928143857}
# Losses {'ner': 16.626024961471558}
# Losses {'ner': 31.323134899139404}
# Losses {'ner': 45.98686349391937}
# Losses {'ner': 58.799731373786926}
# Losses {'ner': 75.82045829296112}
# Losses {'ner': 88.63067400455475}
# Losses {'ner': 107.42686855792999}
# Losses {'ner': 122.58527994155884}
# Losses {'ner': 124.6786330488485}
# Losses {'ner': 17.56293487548828}
# Losses {'ner': 31.234185814857483}
# Losses {'ner': 46.26130926609039}
# Losses {'ner': 56.13612896203995}
# Losses {'ner': 68.72938659787178}
# Losses {'ner': 80.7388416826725}
# Losses {'ner': 93.23811259865761}
# Losses {'ner': 111.35312262177467}
# Losses {'ner': 115.99088495969772}
# Losses {'ner': 14.664009809494019}
# Losses {'ner': 34.106099367141724}
# Losses {'ner': 44.1631835103035}
# Losses {'ner': 56.43685120344162}
# Losses {'ner': 72.38885229825974}
# Losses {'ner': 86.11912506818771}
# Losses {'ner': 104.23864322900772}
# Losses {'ner': 118.43296855688095}
# Losses {'ner': 122.38553991168737}
# Losses {'ner': 12.200793027877808}
# Losses {'ner': 24.757194757461548}
# Losses {'ner': 41.26260823011398}
# Losses {'ner': 53.55549997091293}
# Losses {'ner': 72.79105585813522}
# Losses {'ner': 83.36295938491821}
# Losses {'ner': 103.62386417388916}
# Losses {'ner': 119.18413090705872}
# Losses {'ner': 122.29478453099728}
# Losses {'ner': 14.185591459274292}
# Losses {'ner': 30.37746024131775}
# Losses {'ner': 45.0772922039032}
# Losses {'ner': 50.21720115840435}
# Losses {'ner': 67.1298860758543}
# Losses {'ner': 82.82315699756145}
# Losses {'ner': 106.00672523677349}
# Losses {'ner': 122.83551041781902}
# Losses {'ner': 128.5718654873781}
# Losses {'ner': 10.68309211730957}
# Losses {'ner': 25.49665880203247}
# Losses {'ner': 40.55737566947937}
# Losses {'ner': 57.92235791683197}
# Losses {'ner': 78.59869515895844}
# Losses {'ner': 95.37130725383759}
# Losses {'ner': 113.51866567134857}
# Losses {'ner': 126.94012987613678}
# Losses {'ner': 129.0451929315459}
# Losses {'ner': 13.31723427772522}
# Losses {'ner': 26.74462580680847}
# Losses {'ner': 42.57588839530945}
# Losses {'ner': 54.8056275844574}
# Losses {'ner': 68.94674551486969}
# Losses {'ner': 80.799325466156}
# Losses {'ner': 93.26005971431732}
# Losses {'ner': 104.52330505847931}
# Losses {'ner': 109.818150552921}
# Losses {'ner': 17.931918919086456}
# Losses {'ner': 34.38168269395828}
# Losses {'ner': 43.58084920048714}
# Losses {'ner': 60.20393946766853}
# Losses {'ner': 71.69080498814583}
# Losses {'ner': 90.18112042546272}
# Losses {'ner': 104.74703016877174}
# Losses {'ner': 129.95609417557716}
# Losses {'ner': 133.1975034584866}
# Losses {'ner': 13.049356341362}
# Losses {'ner': 33.87018001079559}
# Losses {'ner': 51.34208023548126}
# Losses {'ner': 66.40624439716339}
# Losses {'ner': 83.90224957466125}
# Losses {'ner': 96.83755934238434}
# Losses {'ner': 106.87362012267113}
# Losses {'ner': 124.4672631919384}
# Losses {'ner': 127.8529628883116}
# Losses {'ner': 15.967081308364868}
# Losses {'ner': 28.690710306167603}
# Losses {'ner': 44.475051283836365}
# Losses {'ner': 56.95190131664276}
# Losses {'ner': 74.8365627527237}
# Losses {'ner': 86.1840683221817}
# Losses {'ner': 102.64412486553192}
# Losses {'ner': 118.9028822183609}
# Losses {'ner': 120.36877517779158}
# Losses {'ner': 14.480674624443054}
# Losses {'ner': 25.955079674720764}
# Losses {'ner': 42.4648574590683}
# Losses {'ner': 55.2917503118515}
# Losses {'ner': 76.18389856815338}
# Losses {'ner': 91.15159606933594}
# Losses {'ner': 106.53328204154968}
# Losses {'ner': 116.44996738433838}
# Losses {'ner': 118.4337236203719}
# Losses {'ner': 21.155734539031982}
# Losses {'ner': 35.3677933216095}
# Losses {'ner': 53.84861373901367}
# Losses {'ner': 65.18633449077606}
# Losses {'ner': 80.21234846115112}
# Losses {'ner': 94.53035616874695}
# Losses {'ner': 110.62681221961975}
# Losses {'ner': 126.49985146522522}
# Losses {'ner': 127.6517341003746}
# Losses {'ner': 9.830824844539165}
# Losses {'ner': 22.689377300441265}
# Losses {'ner': 33.27823232859373}
# Losses {'ner': 56.0633010789752}
# Losses {'ner': 67.49540757387877}
# Losses {'ner': 81.24088656157255}
# Losses {'ner': 95.93402325361967}
# Losses {'ner': 113.9993761703372}
# Losses {'ner': 118.77898793667555}
# Losses {'ner': 10.767479300498962}
# Losses {'ner': 23.60119378566742}
# Losses {'ner': 35.96006143093109}
# Losses {'ner': 51.94905865192413}
# Losses {'ner': 71.15153133869171}
# Losses {'ner': 82.43262976408005}
# Losses {'ner': 104.81322830915451}
# Losses {'ner': 114.60948830842972}
# Losses {'ner': 117.94838102441281}
# Losses {'ner': 16.097910404205322}
# Losses {'ner': 29.491870760917664}
# Losses {'ner': 46.32227432727814}
# Losses {'ner': 59.426923632621765}
# Losses {'ner': 74.31009018421173}
# Losses {'ner': 92.88680684566498}
# Losses {'ner': 110.21910440921783}
# Losses {'ner': 120.08727446198463}
# Losses {'ner': 124.90805020928383}
# Losses {'ner': 19.138991832733154}
# Losses {'ner': 30.3406143784523}
# Losses {'ner': 48.88614684343338}
# Losses {'ner': 58.79923766851425}
# Losses {'ner': 75.3500148653984}
# Losses {'ner': 87.23093169927597}
# Losses {'ner': 104.47349661588669}
# Losses {'ner': 120.63153594732285}
# Losses {'ner': 122.43169663957087}
# Losses {'ner': 17.048858642578125}
# Losses {'ner': 34.881720542907715}
# Losses {'ner': 52.8955078125}
# Losses {'ner': 69.08579802513123}
# Losses {'ner': 80.07752442359924}
# Losses {'ner': 97.16938090324402}
# Losses {'ner': 112.071462392807}
# Losses {'ner': 124.331019282341}
# Losses {'ner': 128.06228264945094}
# Losses {'ner': 11.724002361297607}
# Losses {'ner': 24.88077223300934}
# Losses {'ner': 37.5823620557785}
# Losses {'ner': 54.895912528038025}
# Losses {'ner': 71.94569277763367}
# Losses {'ner': 93.24581503868103}
# Losses {'ner': 109.50615167617798}
# Losses {'ner': 130.36154794692993}
# Losses {'ner': 132.64106407761574}
# Losses {'ner': 19.50439476966858}
# Losses {'ner': 41.56724739074707}
# Losses {'ner': 50.60834360122681}
# Losses {'ner': 67.66580510139465}
# Losses {'ner': 77.83649650216103}
# Losses {'ner': 90.43756273388863}
# Losses {'ner': 105.23726347088814}
# Losses {'ner': 118.04376342892647}
# Losses {'ner': 120.1006481210934}
# Losses {'ner': 14.610825896263123}
# Losses {'ner': 23.312998175621033}
# Losses {'ner': 40.87713420391083}
# Losses {'ner': 58.09253466129303}
# Losses {'ner': 66.52600067853928}
# Losses {'ner': 82.54088515043259}
# Losses {'ner': 94.03100115060806}
# Losses {'ner': 101.54999253153801}
# Losses {'ner': 104.97989850390638}
# Losses {'ner': 15.104919195175171}
# Losses {'ner': 29.26757061481476}
# Losses {'ner': 40.36914575099945}
# Losses {'ner': 58.10701358318329}
# Losses {'ner': 80.45377194881439}
# Losses {'ner': 91.39194107055664}
# Losses {'ner': 113.23857402801514}
# Losses {'ner': 123.52198588848114}
# Losses {'ner': 125.04731564072426}
# Losses {'ner': 14.080317735671997}
# Losses {'ner': 26.994571685791016}
# Losses {'ner': 40.156008183956146}
# Losses {'ner': 51.2917845249176}
# Losses {'ner': 67.80273485183716}
# Losses {'ner': 89.27990484237671}
# Losses {'ner': 107.54132843017578}
# Losses {'ner': 118.59110188484192}
# Losses {'ner': 121.32323174661998}
# Losses {'ner': 14.123390316963196}
# Losses {'ner': 35.76864397525787}
# Losses {'ner': 55.32499420642853}
# Losses {'ner': 68.29133260250092}
# Losses {'ner': 83.28303635120392}
# Losses {'ner': 94.91846519708633}
# Losses {'ner': 107.00314491987228}
# Losses {'ner': 114.25657561421394}
# Losses {'ner': 120.21311985317152}
# Losses {'ner': 16.532769203186035}
# Losses {'ner': 29.569173574447632}
# Losses {'ner': 38.023357735946774}
# Losses {'ner': 51.41822801716626}
# Losses {'ner': 68.93355523236096}
# Losses {'ner': 82.63209031708539}
# Losses {'ner': 100.06133102066815}
# Losses {'ner': 118.81363319046795}
# Losses {'ner': 122.53754393942654}
# Losses {'ner': 16.780147314071655}
# Losses {'ner': 36.31783962249756}
# Losses {'ner': 45.37686267495155}
# Losses {'ner': 63.9743290245533}
# Losses {'ner': 75.71300539001822}
# Losses {'ner': 88.75649663433433}
# Losses {'ner': 96.99309834465384}
# Losses {'ner': 114.51835688576102}
# Losses {'ner': 118.1773290246274}
# Losses {'ner': 13.758941769599915}
# Losses {'ner': 29.914826154708862}
# Losses {'ner': 43.04660552740097}
# Losses {'ner': 58.77222281694412}
# Losses {'ner': 68.87100750207901}
# Losses {'ner': 82.79162567853928}
# Losses {'ner': 95.31390875577927}
# Losses {'ner': 113.576121032238}
# Losses {'ner': 117.17506164684892}
# Losses {'ner': 12.130340337753296}
# Losses {'ner': 28.51363968849182}
# Losses {'ner': 42.10657811164856}
# Losses {'ner': 56.24639093875885}
# Losses {'ner': 76.7169781923294}
# Losses {'ner': 88.92159223556519}
# Losses {'ner': 103.96441912651062}
# Losses {'ner': 116.86896705627441}
# Losses {'ner': 120.96646628869348}
# Losses {'ner': 13.383673667907715}
# Losses {'ner': 26.540535807609558}
# Losses {'ner': 42.90637123584747}
# Losses {'ner': 54.60408270359039}
# Losses {'ner': 74.66475665569305}
# Losses {'ner': 89.45873546600342}
# Losses {'ner': 107.95944619178772}
# Losses {'ner': 118.73639160394669}
# Losses {'ner': 122.35684774816036}
# Losses {'ner': 13.577259182929993}
# Losses {'ner': 28.15748679637909}
# Losses {'ner': 38.86820185184479}
# Losses {'ner': 48.26707088947296}
# Losses {'ner': 56.89159017801285}
# Losses {'ner': 69.25988441705704}
# Losses {'ner': 85.5166717171669}
# Losses {'ner': 97.56795817613602}
# Losses {'ner': 101.10737180523574}
# Losses {'ner': 14.412599563598633}
# Losses {'ner': 27.42776370048523}
# Losses {'ner': 44.86260437965393}
# Losses {'ner': 58.30544435977936}
# Losses {'ner': 70.61869633197784}
# Losses {'ner': 83.71745347976685}
# Losses {'ner': 98.3611090183258}
# Losses {'ner': 108.7497911453247}
# Losses {'ner': 110.71399745473173}
# Losses {'ner': 21.107946157455444}
# Losses {'ner': 40.03775930404663}
# Losses {'ner': 53.81430506706238}
# Losses {'ner': 69.65850394964218}
# Losses {'ner': 82.54678398370743}
# Losses {'ner': 96.68292146921158}
# Losses {'ner': 108.95884221792221}
# Losses {'ner': 119.10838389396667}
# Losses {'ner': 122.99256378412247}
# Losses {'ner': 16.11606192588806}
# Losses {'ner': 30.76805353164673}
# Losses {'ner': 49.1001410484314}
# Losses {'ner': 64.72807765007019}
# Losses {'ner': 79.04106724262238}
# Losses {'ner': 84.94223341718316}
# Losses {'ner': 101.55321440473199}
# Losses {'ner': 119.5582304932177}
# Losses {'ner': 123.41011178866029}
# Losses {'ner': 17.78749966621399}
# Losses {'ner': 33.11657536029816}
# Losses {'ner': 48.14702832698822}
# Losses {'ner': 59.31075710058212}
# Losses {'ner': 72.30629706382751}
# Losses {'ner': 83.62947249412537}
# Losses {'ner': 96.07413446903229}
# Losses {'ner': 114.09018409252167}
# Losses {'ner': 117.41324850881938}
# Losses {'ner': 19.22999405860901}
# Losses {'ner': 38.96400547027588}
# Losses {'ner': 49.45887053012848}
# Losses {'ner': 61.55673158168793}
# Losses {'ner': 75.81415390968323}
# Losses {'ner': 91.819833278656}
# Losses {'ner': 104.46522223949432}
# Losses {'ner': 117.52846395969391}
# Losses {'ner': 119.19688073468393}
# Losses {'ner': 16.544594049453735}
# Losses {'ner': 32.94842630624771}
# Losses {'ner': 49.41717320680618}
# Losses {'ner': 64.23375278711319}
# Losses {'ner': 77.6990470290184}
# Losses {'ner': 97.6977636218071}
# Losses {'ner': 112.61351078748703}
# Losses {'ner': 129.89575344324112}
# Losses {'ner': 133.6548449958209}
# Losses {'ner': 12.069720089435577}
# Losses {'ner': 31.371930420398712}
# Losses {'ner': 44.77249199151993}
# Losses {'ner': 58.07486993074417}
# Losses {'ner': 66.29808855243027}
# Losses {'ner': 79.71781802363694}
# Losses {'ner': 99.30682182498276}
# Losses {'ner': 112.54643356986344}
# Losses {'ner': 115.45494712190703}
# Losses {'ner': 12.515192210674286}
# Losses {'ner': 27.259598433971405}
# Losses {'ner': 41.400281608104706}
# Losses {'ner': 54.60128778219223}
# Losses {'ner': 71.45838731527328}
# Losses {'ner': 83.53990072011948}
# Losses {'ner': 98.17579764127731}
# Losses {'ner': 110.89145773649216}
# Losses {'ner': 113.16763110121246}
# Losses {'ner': 11.647818565368652}
# Losses {'ner': 23.349749764427543}
# Losses {'ner': 41.61131866835058}
# Losses {'ner': 51.169972917065024}
# Losses {'ner': 73.20362522266805}
# Losses {'ner': 85.88987924717367}
# Losses {'ner': 98.46149780414999}
# Losses {'ner': 113.77666451595724}
# Losses {'ner': 116.73212852142751}
# Losses {'ner': 16.27556347846985}
# Losses {'ner': 28.996672868728638}
# Losses {'ner': 43.05536508560181}
# Losses {'ner': 53.028529047966}
# Losses {'ner': 62.53974312543869}
# Losses {'ner': 75.41106802225113}
# Losses {'ner': 84.05476021766663}
# Losses {'ner': 96.09129273891449}
# Losses {'ner': 100.55883224849822}
# Losses {'ner': 11.79886507987976}
# Losses {'ner': 25.053672194480896}
# Losses {'ner': 40.98800528049469}
# Losses {'ner': 52.26134532690048}
# Losses {'ner': 61.9727064371109}
# Losses {'ner': 76.33270370960236}
# Losses {'ner': 89.83166074752808}
# Losses {'ner': 104.20897650718689}
# Losses {'ner': 107.20927384868264}
# Losses {'ner': 14.604618549346924}
# Losses {'ner': 27.927368760108948}
# Losses {'ner': 38.051625818014145}
# Losses {'ner': 54.785862892866135}
# Losses {'ner': 66.62699458003044}
# Losses {'ner': 81.169274777174}
# Losses {'ner': 93.45262315869331}
# Losses {'ner': 106.11554124951363}
# Losses {'ner': 106.17577893167902}
# Losses {'ner': 18.01383876800537}
# Losses {'ner': 33.43786108493805}
# Losses {'ner': 52.283713936805725}
# Losses {'ner': 65.09559381008148}
# Losses {'ner': 86.04104900360107}
# Losses {'ner': 101.19974422454834}
# Losses {'ner': 116.4147607088089}
# Losses {'ner': 135.05101025104523}
# Losses {'ner': 138.23286309357354}
# Losses {'ner': 16.930417776107788}
# Losses {'ner': 34.6289598941803}
# Losses {'ner': 50.40509009361267}
# Losses {'ner': 64.07038116455078}
# Losses {'ner': 79.7507541179657}
# Losses {'ner': 87.14708557724953}
# Losses {'ner': 100.44842520356178}
# Losses {'ner': 114.49996545910835}
# Losses {'ner': 118.8581378981471}
# Losses {'ner': 16.75954031944275}
# Losses {'ner': 35.017895460128784}
# Losses {'ner': 45.23254030942917}
# Losses {'ner': 57.75007373094559}
# Losses {'ner': 67.6827729344368}
# Losses {'ner': 85.14317494630814}
# Losses {'ner': 101.36493343114853}
# Losses {'ner': 116.94969815015793}
# Losses {'ner': 119.43984917760827}
# Losses {'ner': 25.220730304718018}
# Losses {'ner': 39.20811700820923}
# Losses {'ner': 50.709717750549316}
# Losses {'ner': 60.959750056266785}
# Losses {'ner': 72.88489699363708}
# Losses {'ner': 86.39099788665771}
# Losses {'ner': 100.51755142211914}
# Losses {'ner': 115.68904316425323}
# Losses {'ner': 118.56191751360893}
# Losses {'ner': 11.524488508701324}
# Losses {'ner': 25.894663274288177}
# Losses {'ner': 41.3848072886467}
# Losses {'ner': 50.283149898052216}
# Losses {'ner': 63.92009276151657}
# Losses {'ner': 72.36350589990616}
# Losses {'ner': 91.72646397352219}
# Losses {'ner': 109.5770612359047}
# Losses {'ner': 111.55088702589421}
# Losses {'ner': 13.399875164031982}
# Losses {'ner': 29.853291749954224}
# Losses {'ner': 46.33189570903778}
# Losses {'ner': 62.05248212814331}
# Losses {'ner': 78.6238374710083}
# Losses {'ner': 92.03827548027039}
# Losses {'ner': 106.70922589302063}
# Losses {'ner': 122.409024477005}
# Losses {'ner': 128.62655752897263}
# Losses {'ner': 10.587117969989777}
# Losses {'ner': 22.913680732250214}
# Losses {'ner': 33.08242243528366}
# Losses {'ner': 44.10496073961258}
# Losses {'ner': 58.370761692523956}
# Losses {'ner': 71.82859414815903}
# Losses {'ner': 90.20104545354843}
# Losses {'ner': 104.58333104848862}
# Losses {'ner': 107.99645427049836}
# Losses {'ner': 15.831695079803467}
# Losses {'ner': 32.132556676864624}
# Losses {'ner': 56.66776466369629}
# Losses {'ner': 73.84902691841125}
# Losses {'ner': 89.97809982299805}
# Losses {'ner': 102.68769669532776}
# Losses {'ner': 117.87064862251282}
# Losses {'ner': 131.65356278419495}
# Losses {'ner': 132.66758220200427}
# Losses {'ner': 8.625408411026001}
# Losses {'ner': 15.697946508880705}
# Losses {'ner': 30.54667611932382}
# Losses {'ner': 47.35735746240243}
# Losses {'ner': 61.98035236215219}
# Losses {'ner': 79.80276532983407}
# Losses {'ner': 92.10151012754068}
# Losses {'ner': 108.94355138158426}
# Losses {'ner': 111.81957836961374}
# Losses {'ner': 12.537634491920471}
# Losses {'ner': 30.374096989631653}
# Losses {'ner': 50.07632863521576}
# Losses {'ner': 61.82252722978592}
# Losses {'ner': 76.65679031610489}
# Losses {'ner': 88.1263821721077}
# Losses {'ner': 97.61746245622635}
# Losses {'ner': 111.54862385988235}
# Losses {'ner': 116.67793780565262}
# Losses {'ner': 14.979119539260864}
# Losses {'ner': 30.87998855113983}
# Losses {'ner': 47.51398313045502}
# Losses {'ner': 63.1884423494339}
# Losses {'ner': 78.2197116613388}
# Losses {'ner': 88.12222504615784}
# Losses {'ner': 106.08786177635193}
# Losses {'ner': 115.91565823554993}
# Losses {'ner': 120.07835052907467}

# %%
print(test1)
for ent in test1.ents:
    print(ent.text, ent.label_)
# Out:
# Aradhita wants a cat. Her cat wants a dog. But horses are the best.
# Aradhita ORG

# %%
test2 = nlp("Rabbits are nice.")
test3 = nlp("Shriya is nice")
test4 = nlp("Roland owns a watch.")
test5 = nlp("I saw a snake today.")

# %%
print(test2)
displacy.render(test2, style="ent")
# Out:
# Rabbits are nice.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rabbits
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANIMALS</span>
# </mark>
#  are nice.</div></span>

# %%
print(test3)
displacy.render(test3, style="ent")
# Out:
# Shriya is nice
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shriya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is nice</div></span>

# %%
print(test4)
displacy.render(test4, style="ent")
# Out:
# Roland owns a watch.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  owns a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     watch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# .</div></span>

# %%
print(test5)
displacy.render(test5, style="ent")
# Out:
# I saw a snake today.
# C:\Users\aradh\anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I saw a snake today.</div></span>
